# %% [markdown]
# <a href="https://colab.research.google.com/github/saikirsh/python/blob/main/case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Taylor's Series for Polynomial Equation
# alt text
# alt text
#
# This is simple derivation.
#
# If your observe one term form the above equation for example 12x^4, (where ^ represent power which we are using as a notation), which has been changed to 48x^3 after one derivation
#
# Here is how it is done 👇
#
# 12x^4
#
# 12*4 x^4-1
#
# 48x^3
# Now that, we have done it for one term, we can do it for all the other terms in the equation and finally assemble them together to get a derived equation
#
# if we write a program in python then the output will be like this below
#
# f^(0)(x) = 12x^4+2x^3+6x^2+x^1+1
# f^(1)(x) = 48x^3+6x^2+12x^1+1
# f^(2)(x) = 144x^2+12x^1+12
# f^(3)(x) = 288x^1+12
#
# The final equation is 288x^1+12
# Now we will solve this in a step by step manner
#
# if you take an equation 12x^4+2x^3+6x^2+x^1+1 let us use the process of decomposition
#
# At first write a function derive_term(t) for solving a term in the equation.
# Then we will write a function derive_equation(eq) that is responsible for calling given you the derived equation.
#
# Step 1
# Here we solve for one term
#
# we define a function
#
# def derive_term(t):
#   pass
# If you observe in the equation there are three types of terms in the equation
#
# 12x^3 where you will have a formate of n * x^p
#
# x^2 where you will have a formate of x^p
#
# 12 where you will have only n without x or p
#
# In the above three terms derive_term should only accept the first two types of terms
#
# So you should impose a restriction to which ever is calling this function to only send the first two type of terms and skip the third
#
# Procedure
# Once derive_term function gets a term as a string t, split it into list using t.split('x^') function which will split the string based on "x^"
#
# Take for example a term 12x^2, it will be turned into a list ['12','2']
#
# By type casting them into int let l[0] as l[0]*l[1] and l[1] as l[1]-1
#
# Take for example a term x^4, as there is no number before x
#
# By type casting them into int let l[0] is 1*l[0] and l[1] is l[1]-1
#
# Finally join the list l with 'x^' like this 'x^'.join(l) and return it.
#
# Step 2
# Once the above function is ready, you are now ready to decompose the equation and solve the problem.
#
# we define a function
#
# def derive_equation(eq):
#   pass
# This is the function which receives the equation
#
# Procedure
# Once this function receives the equation and derivation_num, as sring, it should split the equation using the split function based on '+'.
#
# Take for example 12x^4+2x^3+6x^2+x^1+1, which is turned into a list as
# l = ['12x^4', '2x^3', '6x^2', 'x^1', '1']
#
# Call derive_term(t) function and send l[i] term where i, is index
#
# repeat the instruction 3 for each element in list l.
#
# Write a condition to not send a term which is only digit like '1','12', etc.
#
# Only the terms with x, in it should be sent to function derive_term(t)
#
# After receiving back every derive term from derive_term() function, replace the older terms with the newer terms.
#
# join the list l into an eq_string, with '+'
#
# Print the equation eq_string.
#
# Go to instruction 2 for deriving the new eq_string until it satisfies the derivation_num
#
# return the final equation to the caller, in main.py file where it will print the final equation.

# %%
##Main.py
from derive_equation import derive_equation

derivation_num = 3
eq_string = "12x^4+2x^3+6x^2+x^1+1"
print(eq_string)
for i in range(derivation_num):
    eq_string = derive_equation(eq_string)
    print(eq_string)
     





##derive_equation
from derive_term import derive_term

def derive_equation(eq):
    lst=eq.split('+')
    list_eq= []
    for i in lst:
       if 'x^' in i:
           list_eq.append(derive_term(i))
    return ('+').join(list_eq)
    #print(lst)





##derive_term
def derive_term(t):
  list_1 = t.split("x^")
  if list_1[0] == '':
    list_1[0] ='1'
  list_1[0] = int(list_1[0])* int(list_1[1])
  list_1[1] = int(list_1[1]) - 1
  list_1[0] = str(list_1[0])
  list_1[1] = str(list_1[1])
  if list_1[1] == '0':
    eq_string = list_1[0]
  else:
    eq_string = ('x^').join(list_1)
  return eq_string

# %% [markdown]
# Assemblere

# %%
# After reading the document and Interaction with faculty you should be able to convert a hack assembly code into binary here

########################### ASSEMBLER ########################
input = input()
j = 0
for j in range(0,(len(input))):
  if input[j] == 'a':
    print('01000001',end = ' ') 
  if input[j]== 'b':
    print('01000010',end = ' ')
  if input[j]=='c':
    print('01000011',end = ' ')
  if input[j]=='d':
    print('01000100',end = ' ')
  if input[j]=='e':
    print('01000101',end = ' ')
  if input[j]=='f':
    print('01000110',end = ' ')
  if input[j]=='g':
    print('01000111',end = ' ')
  if input[j]=='h':
    print('01001000',end = ' ')
  if input[j]=='i':
    print('01001001',end = ' ')
  if input[j]=='j':
    print('01001010',end = ' ')
  if input[j]=='k':
    print('01001011',end = ' ')
  if input[j]=='l':
    print('01001100',end = ' ')
  if input[j]=='m':
    print('01001101',end = ' ')
  if input[j]=='n':
    print('01001110',end = ' ')
  if input[j]=='o':
    print('01001111',end = ' ')
  if input[j]=='p':
    print('01010000',end = ' ')
  if input[j]=='q':
    print('01010001',end = ' ')
  if input[j]=='r':
    print('01010010',end = ' ')
  if input[j]=='s':
    print('01010011',end = ' ')
  if input[j]=='t':
    print('01010100',end = ' ')
  if input[j]=='u':
    print('01010101',end = ' ')
  if input[j]=='v':
    print('01010110',end = ' ')
  if input[j]=='w':
    print('01010111',end = ' ')
  if input[j]=='x':
    print('01011000',end = ' ')
  if input[j]=='y':
    print('01011001',end = ' ')
  if input[j]=='z':
    print('01011010',end = ' ')
  if input[j] == 'A':
    print('01000001',end = ' ')
  if input[j]== 'B':
    print('01000010',end = ' ')
  if input[j]=='C':
    print('01000011',end = ' ')
  if input[j]=='D':
    print('01000100',end = ' ')
  if input[j]=='E':
    print('01000101',end = ' ')
  if input[j]=='F':
    print('01000110',end = ' ')
  if input[j]=='G':
    print('01000111',end = ' ')
  if input[j]=='H':
    print('01001000',end = ' ')
  if input[j]=='I':
    print('01001001',end = ' ')
  if input[j]=='J':
    print('01001010',end = ' ')
  if input[j]=='K':
    print('01001011',end = ' ')
  if input[j]=='L':
    print('01001100',end = ' ')
  if input[j]=='M':
    print('01001101',end = ' ')
  if input[j]=='N':
    print('01001110',end = ' ')
  if input[j]=='O':
    print('01001111',end = ' ')
  if input[j]=='P':
    print('01010000',end = ' ')
  if input[j]=='Q':
    print('01010001',end = ' ')
  if input[j]=='R':
    print('01010010',end = ' ')
  if input[j]=='S':
    print('01010011',end = ' ')
  if input[j]=='T':
    print('01010100',end = ' ')
  if input[j]=='U':
    print('01010101',end = ' ')
  if input[j]=='V':
    print('01010110',end = ' ')
  if input[j]=='W':
    print('01010111',end = ' ')
  if input[j]=='X':
    print('01011000',end = ' ')
  if input[j]=='Y':
    print('01011001',end = ' ')
  if input[j]=='Z':
    print('01011010',end = ' ')
  if input[j]=='!':
    print('00100001',end = ' ')
  if input[j]=='"':
    print('00100010',end = ' ')
  if input[j]=='#':
    print('00100011',end = ' ')
  if input[j]=='$':
    print('00100100',end = ' ')
  if input[j]=='%':
    print('00100101',end = ' ')
  if input[j]=='&':
    print('00100110',end = ' ')
  if input[j]=="'":
    print('00100111',end = ' ')
  if input[j]=='(':
    print('00101000',end = ' ')
  if input[j]==')':
    print('00101001',end = ' ')
  if input[j]=='*':
    print('00101010',end = ' ')
  if input[j]=='+':
    print('00101011',end = ' ')
  if input[j]==',':
    print('00101100',end = ' ')
  if input[j]=='-':
    print('00101101',end = ' ')
  if input[j]=='.':
    print('00101110',end = ' ')
  if input[j]=='/':
    print('00101111',end = ' ')
  if input[j]=='0':
    print('00110000',end = ' ')
  if input[j]=='1':
    print('00110001',end = ' ')
  if input[j]=='2':
    print('00110010',end = ' ')
  if input[j]=='3':
    print('00110011',end = ' ')
  if input[j]=='4':
    print('00110100',end = ' ')
  if input[j]=='5':
    print('00110101',end = ' ')
  if input[j]=='6':
    print('00110110',end = ' ')
  if input[j]=='7':
    print('00110111',end = ' ')
  if input[j]=='8':
    print('00111000',end = ' ')
  if input[j]=='9':
    print('00111000',end = ' ')
  if input[j]=='?':
    print('00111111',end = ' ')
  if input[j]=='@':
    print('01000000',end = ' ')
  if input[j]==' ':
    print('00100000',end = ' ')

# %% [markdown]
# Spot Light Search Engine
# This is one of Case Study ideas.
#
# In this project, you'll implement a text-based version of a search engine (Spotlight in mac, Google, Bing, Baidu, etc.)!
#
# Please note that this project idea assumes you're all caught up on the lectures about strings, file reading, lists, and dictionaries.
#
# We've provided you with several milestones.
#
# In Milestone 1, as a warm-up, you'll implement the function common(list1, list2), which takes 2 lists and returns a list with only the elements both lists have in common. This function will come in handy later!
#
# In Milestone 2, you'll write code which reads files to store their information in a format that will be easy to query later -- this is called "indexing".
#
# In Milestone 3, you'll implement the actual search functionality! Don't forget to have fun :)

# %%
##Milestone-1-warm-up
main.py
from common_elements import common

def main():
    print("common(['a'], ['a']) returns: ")
    print(common(['a'], ['a']))                             # should print ['a']
    print("common(['a', 'b', 'c'], ['x', 'a', 'z', 'c']) returns:")
    print(common(['a', 'b', 'c'], ['x', 'a', 'z', 'c']))    # should print ['a', 'c']
    print("common(['a', 'b', 'c'], ['x', 'y', 'z']) returns:")
    print(common(['a', 'b', 'c'], ['x', 'y', 'z']))         # should print []
    print("common(['a', 'b', 'c'], ['a', 'a', 'x']) returns:")
    print(common(['a', 'a', 'b'], ['a', 'a', 'x']))         # should print ['a']


if __name__ == '__main__':
    main()




##common elments.py
"""
File: common_elements.py
------------------------
File to implement a function that is passed two lists and returns a new list
containing those elements that appear in both of the lists passed in.
"""


def common(list1, list2):
    """
    This function is passed two lists and returns a new list containing
    those elements that appear in both of the lists passed in.
    >>> common(['a'], ['a'])
    ['a']
    >>> common(['a', 'b', 'c'], ['x', 'a', 'z', 'c'])
    ['a', 'c']
    >>> common(['a', 'b', 'c'], ['x', 'y', 'z'])
    []
    >>> common(['a', 'a', 'b'], ['a', 'a', 'x'])
    ['a']
    """
    a=[]
    for i in list1:
      if i not in a:
        if i in list2:
          a.append(i)
    return a
    """
    You implement this function.  Don't forget to remove the 'pass' statement above.
    """

# %%
##Milestone-2-The-index
##main.py
from searchengine import textfiles_in_dir, create_index
import os
import sys
import string

def main():
    """
    Usage: searchengine.py <file directory> -s
    The first argument specified should be the directory of text files that
    will be indexed/searched.  If the parameter -s is provided, then the
    user can interactively search (using the index).  Otherwise (if -s is
    not included), the index and the dictionary mapping file names to article
    titles are just printed on the console.
    """
    # Get command line arguments
    args = sys.argv[1:]

    num_args = len(args)
    if num_args < 1:
        print('Please specify directory of files to index as first argument.')
    else:
        # args[0] should be the folder containing all the files to index/search.
        directory = args[0]
        if os.path.exists(directory):
            # Build index from files in the given directory
            files = textfiles_in_dir(directory)
            index = {}          # index is empty to start
            file_titles = {}    # mapping of file names to article titles is empty to start
            create_index(files, index, file_titles)

            print('Index:')
            print(index)
            print('File names -> document titles:')
            print(file_titles)
        else:
            print('Directory "' + directory + '" does not exist.')


if __name__ == '__main__':
    main()



##search engine
"""
File: searchengine.py
---------------------
You fill in this comment
"""


import os
import sys
import string


def create_index(filenames, index, file_titles):
    """
    This function is passed:
        filenames:      a list of file names (strings)

        index:          a dictionary mapping from terms to file names (i.e., inverted index)
                        (term -> list of file names that contain that term)

        file_titles:    a dictionary mapping from a file names to the title of the article
                        in a given file
                        (file name -> title of article in that file)

    The function will update the index passed in to include the terms in the files
    in the list filenames.  Also, the file_titles dictionary will be updated to
    include files in the list of filenames.

    >>> index = {}
    >>> file_titles = {}
    >>> create_index(['test1.txt'], index, file_titles)
    >>> index
    {'file': ['test1.txt'], '1': ['test1.txt'], 'title': ['test1.txt'], 'apple': ['test1.txt'], 'ball': ['test1.txt'], 'carrot': ['test1.txt']}
    >>> file_titles
    {'test1.txt': 'File 1 Title'}
    >>> index = {}
    >>> file_titles = {}
    >>> create_index(['test2.txt'], index, file_titles)
    >>> index
    {'file': ['test2.txt'], '2': ['test2.txt'], 'title': ['test2.txt'], 'ball': ['test2.txt'], 'carrot': ['test2.txt'], 'dog': ['test2.txt']}
    >>> file_titles
    {'test2.txt': 'File 2 Title'}
    >>> index = {}
    >>> file_titles = {}
    >>> create_index(['test1.txt', 'test2.txt'], index, file_titles)
    >>> index
    {'file': ['test1.txt', 'test2.txt'], '1': ['test1.txt'], 'title': ['test1.txt', 'test2.txt'], 'apple': ['test1.txt'], 'ball': ['test1.txt', 'test2.txt'], 'carrot': ['test1.txt', 'test2.txt'], '2': ['test2.txt'], 'dog': ['test2.txt']}
    >>> index = {}
    >>> file_titles = {}
    >>> create_index(['test1.txt', 'test2.txt', 'test2.txt'], index, file_titles)
    >>> index
    {'file': ['test1.txt', 'test2.txt'], '1': ['test1.txt'], 'title': ['test1.txt', 'test2.txt'], 'apple': ['test1.txt'], 'ball': ['test1.txt', 'test2.txt'], 'carrot': ['test1.txt', 'test2.txt'], '2': ['test2.txt'], 'dog': ['test2.txt']}
    >>> file_titles
    {'test1.txt': 'File 1 Title', 'test2.txt': 'File 2 Title'}
    >>> index = {'file': ['test1.txt'], '1': ['test1.txt'], 'title': ['test1.txt'], 'apple': ['test1.txt'], 'ball': ['test1.txt'], 'carrot': ['test1.txt']}
    >>> file_titles = {'test1.txt': 'File 1 Title'}
    >>> create_index([], index, file_titles)
    >>> index
    {'file': ['test1.txt'], '1': ['test1.txt'], 'title': ['test1.txt'], 'apple': ['test1.txt'], 'ball': ['test1.txt'], 'carrot': ['test1.txt']}
    >>> file_titles
    {'test1.txt': 'File 1 Title'}
    """
  
    for i  in filenames:
        a=open(i,'r')
        b=a.readlines()
        c=[]
        for j in b:
          d=j.replace('\n',' ').split(' ')
          for z in d:
            if z!='':
              raw = z
              term = raw.strip(string.punctuation).lower()
              c.append(term)
        for ad in c:
          if ad!='':
            if ad in index:
              if i not in index[ad]:
                index[ad].append(i)
            else:
              index[ad]=[]
              if i not in index[ad]:
                index[ad].append(i)
        for ed in b:
          if b.index(ed)==0:
            file_titles[i]=ed.strip('\n')
    """
    You implement this function.  Don't forget to remove the 'pass' statement above.
    """


##### YOU SHOULD NOT NEED TO MODIFY ANY CODE BELOW THIS LINE (UNLESS YOU'RE ADDING EXTENSIONS) #####


def textfiles_in_dir(directory):
    """
    DO NOT MODIFY
    Given the name of a valid directory, returns a list of the .txt
    file names within it.

    Input:
        directory (string): name of directory
    Returns:
        list of (string) names of .txt files in directory
    """
    filenames = []

    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            filenames.append(os.path.join(directory, filename))

    return filenames

# %%
##milestone-3-using index to search
##main.py
import os
import sys
import string
from searchengine_advanced import create_index, do_searches, search, textfiles_in_dir
def main():
    """
    Usage: searchengine.py <file directory> -s
    The first argument specified should be the directory of text files that
    will be indexed/searched.  If the parameter -s is provided, then the
    user can interactively search (using the index).  Otherwise (if -s is
    not included), the index and the dictionary mapping file names to article
    titles are just printed on the console.
    """
    # Get command line arguments
    args = sys.argv[1:]

    num_args = len(args)
    if num_args < 1 or num_args > 2:
        print('Please specify directory of files to index as first argument.')
        print('Add -s to also search (otherwise, index and file titles will just be printed).')
    else:
        # args[0] should be the folder containing all the files to index/search.
        directory = args[0]
        if os.path.exists(directory):
            # Build index from files in the given directory
            files = textfiles_in_dir(directory)
            index = {}          # index is empty to start
            file_titles = {}    # mapping of file names to article titles is empty to start
            create_index(files, index, file_titles)

            # Either allow the user to search using the index, or just print the index
            if num_args == 2 and args[1] == '-s':
                do_searches(index, file_titles)
            else:
                print('Index:')
                print(index)
                print('File names -> document titles:')
                print(file_titles)
        else:
            print('Directory "' + directory + '" does not exist.')


if __name__ == '__main__':
    main()





##searchengine-advanced.py
"""
File: searchengine.py
---------------------
You fill in this comment
"""


import os
import sys
import string


def create_index(filenames, index, file_titles):
    """
    This function is passed:
        filenames:      a list of file names (strings)

        index:          a dictionary mapping from terms to file names (i.e., inverted index)
                        (term -> list of file names that contain that term)

        file_titles:    a dictionary mapping from a file names to the title of the article
                        in a given file
                        (file name -> title of article in that file)

    The function will update the index passed in to include the terms in the files
    in the list filenames.  Also, the file_titles dictionary will be updated to
    include files in the list of filenames.

    >>> index = {}
    >>> file_titles = {}
    >>> create_index(['test1.txt'], index, file_titles)
    >>> index
    {'file': ['test1.txt'], '1': ['test1.txt'], 'title': ['test1.txt'], 'apple': ['test1.txt'], 'ball': ['test1.txt'], 'carrot': ['test1.txt']}
    >>> file_titles
    {'test1.txt': 'File 1 Title'}
    >>> index = {}
    >>> file_titles = {}
    >>> create_index(['test2.txt'], index, file_titles)
    >>> index
    {'file': ['test2.txt'], '2': ['test2.txt'], 'title': ['test2.txt'], 'ball': ['test2.txt'], 'carrot': ['test2.txt'], 'dog': ['test2.txt']}
    >>> file_titles
    {'test2.txt': 'File 2 Title'}
    >>> index = {}
    >>> file_titles = {}
    >>> create_index(['test1.txt', 'test2.txt'], index, file_titles)
    >>> index
    {'file': ['test1.txt', 'test2.txt'], '1': ['test1.txt'], 'title': ['test1.txt', 'test2.txt'], 'apple': ['test1.txt'], 'ball': ['test1.txt', 'test2.txt'], 'carrot': ['test1.txt', 'test2.txt'], '2': ['test2.txt'], 'dog': ['test2.txt']}
    >>> index = {}
    >>> file_titles = {}
    >>> create_index(['test1.txt', 'test2.txt', 'test2.txt'], index, file_titles)
    >>> index
    {'file': ['test1.txt', 'test2.txt'], '1': ['test1.txt'], 'title': ['test1.txt', 'test2.txt'], 'apple': ['test1.txt'], 'ball': ['test1.txt', 'test2.txt'], 'carrot': ['test1.txt', 'test2.txt'], '2': ['test2.txt'], 'dog': ['test2.txt']}
    >>> file_titles
    {'test1.txt': 'File 1 Title', 'test2.txt': 'File 2 Title'}
    >>> index = {'file': ['test1.txt'], '1': ['test1.txt'], 'title': ['test1.txt'], 'apple': ['test1.txt'], 'ball': ['test1.txt'], 'carrot': ['test1.txt']}
    >>> file_titles = {'test1.txt': 'File 1 Title'}
    >>> create_index([], index, file_titles)
    >>> index
    {'file': ['test1.txt'], '1': ['test1.txt'], 'title': ['test1.txt'], 'apple': ['test1.txt'], 'ball': ['test1.txt'], 'carrot': ['test1.txt']}
    >>> file_titles
    {'test1.txt': 'File 1 Title'}
    """
    for i in filenames:
        a=open(i,'r')
        b=a.readlines()
        c=[]
        for j in b:
          d=j.replace('\n',' ').split(' ')
          for z in d:
            if z!='':
              raw = z
              term = raw.strip(string.punctuation).lower()
              c.append(term)
        for ad in c:
          if ad!='':
            if ad in index:
              if i not in index[ad]:
                index[ad].append(i)
            else:
              index[ad]=[]
              if i not in index[ad]:
                index[ad].append(i)
        for ed in b:
          if b.index(ed)==0:
            file_titles[i]=ed.strip('\n')
    """
    You implement this function.  Don't forget to remove the 'pass' statement above.
    """


def search(index, query):
    """
    This function is passed:
        index:      a dictionary mapping from terms to file names (inverted index)
                    (term -> list of file names that contain that term)

        query  :    a query (string), where any letters will be lowercase

    The function returns a list of the names of all the files that contain all of the
    terms in the query (using the index passed in).

    >>> index = {}
    >>> create_index(['test1.txt', 'test2.txt'], index, {})
    >>> search(index, 'apple')
    ['test1.txt']
    >>> search(index, 'ball')
    ['test1.txt', 'test2.txt']
    >>> search(index, 'file')
    ['test1.txt', 'test2.txt']
    >>> search(index, '2')
    ['test2.txt']
    >>> search(index, 'carrot')
    ['test1.txt', 'test2.txt']
    >>> search(index, 'dog')
    ['test2.txt']
    >>> search(index, 'nope')
    []
    >>> search(index, 'apple carrot')
    ['test1.txt']
    >>> search(index, 'apple ball file')
    ['test1.txt']
    >>> search(index, 'apple ball nope')
    []
    """

    b=[]
    c=[]
    a=query.split(' ')
    for i in index:
      for j in a:
        if i==j:
          for ii in index[i]:
            b.append(ii)
    for i in b:
      if b.count(i)==len(a):
        if i not in c:
          c.append(i)
    return c
    """
    You implement this function.  Don't forget to remove the 'pass' statement above.
    """


##### YOU SHOULD NOT NEED TO MODIFY ANY CODE BELOW THIS LINE (UNLESS YOU'RE ADDING EXTENSIONS) #####


def do_searches(index, file_titles):
    """
    This function is given an inverted index and a dictionary mapping from
    file names to the titles of articles in those files.  It allows the user
    to run searches against the data in that index.
    """
    while True:
        query = input("Query (empty query to stop): ")
        query = query.lower()                   # convert query to lowercase
        if query == '':
            break
        results = search(index, query)

        # display query results
        print("Results for query '" + query + "':")
        if results:                             # check for non-empty results list
            for i in range(len(results)):
                title = file_titles[results[i]]
                print(str(i + 1) + ".  Title: " + title + ",  File: " + results[i])
        else:
            print("No results match that query.")


def textfiles_in_dir(directory):
    """
    DO NOT MODIFY
    Given the name of a valid directory, returns a list of the .txt
    file names within it.

    Input:
        directory (string): name of directory
    Returns:
        list of (string) names of .txt files in directory
    """
    filenames = []

    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            filenames.append(os.path.join(directory, filename))
          
    return filenames
